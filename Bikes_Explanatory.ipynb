# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import pandas as pd
# %matplotlib inline

# %%
data=pd.read_csv('bikes_cleaned.csv',)

# %%
data.head()
# Out:
#    Unnamed: 0  duration_sec               start_time                 end_time  \
# 0           6          1147  2019-02-28 23:55:35.104  2019-03-01 00:14:42.588
# 1           9          1049  2019-02-28 23:49:47.699  2019-03-01 00:07:17.025
# 2          10           458  2019-02-28 23:57:57.211  2019-03-01 00:05:35.435
# 3          11           506  2019-02-28 23:56:55.540  2019-03-01 00:05:21.733
# 4          12          1176  2019-02-28 23:45:12.651  2019-03-01 00:04:49.184
#
#    start_station_id                                 start_station_name  \
# 0             300.0                               Palm St at Willow St
# 1              19.0                               Post St at Kearny St
# 2             370.0                                Jones St at Post St
# 3              44.0  Civic Center/UN Plaza BART Station (Market St ...
# 4             127.0                             Valencia St at 21st St
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# ...

# %%
data=data.iloc[:,1:]

# %%
data.head()
# Out:
#    duration_sec               start_time                 end_time  \
# 0          1147  2019-02-28 23:55:35.104  2019-03-01 00:14:42.588
# 1          1049  2019-02-28 23:49:47.699  2019-03-01 00:07:17.025
# 2           458  2019-02-28 23:57:57.211  2019-03-01 00:05:35.435
# 3           506  2019-02-28 23:56:55.540  2019-03-01 00:05:21.733
# 4          1176  2019-02-28 23:45:12.651  2019-03-01 00:04:49.184
#
#    start_station_id                                 start_station_name  \
# 0             300.0                               Palm St at Willow St
# 1              19.0                               Post St at Kearny St
# 2             370.0                                Jones St at Post St
# 3              44.0  Civic Center/UN Plaza BART Station (Market St ...
# 4             127.0                             Valencia St at 21st St
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 0               37.317298              -121.884995           312.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152821 entries, 0 to 152820
# Data columns (total 22 columns):
# duration_sec               152821 non-null int64
# start_time                 152821 non-null object
# end_time                   152821 non-null object
# start_station_id           152821 non-null float64
# start_station_name         152821 non-null object
# start_station_latitude     152821 non-null float64
# start_station_longitude    152821 non-null float64
# end_station_id             152821 non-null float64
# end_station_name           152821 non-null object
# end_station_latitude       152821 non-null float64
# end_station_longitude      152821 non-null float64
# bike_id                    152821 non-null int64
# user_type                  152821 non-null object
# member_birth_year          152821 non-null int64
# member_gender              152821 non-null object
# bike_share_for_all_trip    152821 non-null object
# ...

# %%
data['start_time']=pd.to_datetime(data['start_time'])
data['end_time']=pd.to_datetime(data['end_time'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152821 entries, 0 to 152820
# Data columns (total 22 columns):
# duration_sec               152821 non-null int64
# start_time                 152821 non-null datetime64[ns]
# end_time                   152821 non-null datetime64[ns]
# start_station_id           152821 non-null float64
# start_station_name         152821 non-null object
# start_station_latitude     152821 non-null float64
# start_station_longitude    152821 non-null float64
# end_station_id             152821 non-null float64
# end_station_name           152821 non-null object
# end_station_latitude       152821 non-null float64
# end_station_longitude      152821 non-null float64
# bike_id                    152821 non-null int64
# user_type                  152821 non-null object
# member_birth_year          152821 non-null int64
# member_gender              152821 non-null object
# bike_share_for_all_trip    152821 non-null object
# ...

# %%
plt.figure(figsize=(14,7))
sns.countplot(data=data,x='start_hour',color=sns.color_palette()[0])
plt.xlabel('Start_Hour',fontsize=20)
plt.ylabel('Count',fontsize=20)
plt.title('Hours trips Peaks',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=data,x='day_of_week_start',color=sns.color_palette()[0])
plt.xticks(rotation=15)
plt.title('Most days of Weeks Trips',fontsize=20)
plt.xlabel('days of WEEK',fontsize=20)
plt.ylabel('Count',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(14,7))
data.groupby('member_gender')['duration_min'].sum().plot(kind='bar')
plt.ylabel('total duration by mins ',fontsize=14)
plt.title('Which member gender lasts longer',fontsize=20)
plt.xlabel('member Gender',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(14,7))
sns.countplot(data.member_gender)
plt.title('user gender count',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(14,7))
data.groupby('member_gender')['duration_min'].mean().plot(kind='bar')
plt.ylabel('Avg duration by mins ',fontsize=14)
plt.title('Which member gender lasts longer By Average',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(20,10))
data.member_gender.value_counts(normalize=True).plot(kind='pie',autopct='%1.1f%%',shadow=True,fontsize=14)
plt.title('our members gender percentage',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(20,10))
data.groupby(['member_gender','user_type'])['duration_min'].count().sort_values().plot(kind='barh')
plt.xticks(rotation=15,fontsize=16)
plt.yticks(fontsize=16)
plt.title('The relationship between member_gender , user_type , Number of rides ',fontsize=20)
plt.xlabel('Number of Trips',fontsize=16)
plt.show()

# %%
plt.figure(figsize=(20,10))
data.groupby(['member_gender','user_type'])['duration_min'].mean().sort_values().plot(kind='barh')
plt.xticks(rotation=15,fontsize=16)
plt.yticks(fontsize=16)
plt.title('The relationship between member_gender , user_type , avg_duration',fontsize=20)
plt.xlabel('Duration Mins',fontsize=16)
plt.show()

# %%
# !jupyter nbconvert Bikes_Explanatory.ipynb --to slides --post serve --no-input --no-prompt
# Out:
# [NbConvertApp] Converting notebook Bikes_Explanatory.ipynb to slides
# [NbConvertApp] Writing 519302 bytes to Bikes_Explanatory.slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.5.0
# Traceback (most recent call last):
#   File "C:\Users\20115\Anaconda3\Scripts\jupyter-nbconvert-script.py", line 10, in <module>
#     sys.exit(main())
#   File "C:\Users\20115\Anaconda3\lib\site-packages\jupyter_core\application.py", line 266, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "C:\Users\20115\Anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\20115\Anaconda3\lib\site-packages\nbconvert\nbconvertapp.py", line 337, in start
#     self.convert_notebooks()
#   File "C:\Users\20115\Anaconda3\lib\site-packages\nbconvert\nbconvertapp.py", line 507, in convert_notebooks
# ...
